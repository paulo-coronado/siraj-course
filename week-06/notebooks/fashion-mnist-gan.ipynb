# %%
import sys
import os

# %%
cwd = os.getcwd()
root = os.path.dirname(cwd)
notbooks = os.path.join(root,'notebooks')

scripts = os.path.join(root,'scripts')
model_scripts = os.path.join(root,'scripts','models')
gan_model_scripts = os.path.join(root,'scripts','models','gan.py')

models = os.path.join(root,'models')

# %%
sys.path.append(scripts)
sys.path.append(model_scripts)
sys.path.append(gan_model_scripts)

# %%
# sys.path

# %%
from models.gan import GAN
# Out:
# Using TensorFlow backend.

# %%
gan=GAN()
gan.batch_size=64
# Out:
# ...
# Discriminator
# ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 10, 10, 128)       1280
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 10, 10, 128)       512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 10, 10, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 256)         295168
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 6, 6, 256)         0
# _________________________________________________________________
# ...

# %%
gan.train(epochs=3000, sample_interval=50)
# Out:
# random image shape (64, 28, 28, 1)
# generated image shape (64, 28, 28, 1)
# ===EPOCH 0===
# 0 [D loss: 0.816582, acc.: 49.22%] [G loss: 0.667873]
# ===EPOCH 50===
# 50 [D loss: 5.387170, acc.: 32.03%] [G loss: 0.000054]
# ===EPOCH 100===
# 100 [D loss: 5.541615, acc.: 30.47%] [G loss: 0.000041]
# ===EPOCH 150===
# 150 [D loss: 5.524322, acc.: 32.03%] [G loss: 0.000040]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e835a16e530f> in <module>
# ----> 1 gan.train(epochs=3000, sample_interval=50)
#
# C:\projects\ml-gan-fashion\scripts\models\gan.py in train(self, epochs, sample_interval)
#     216
#     217             # Train the generator (to have the discriminator label samples as valid)
# --> 218             g_loss = self.combined.train_on_batch(noise, valid)
#     219
#     220             g_losses.append(g_loss)
#
# ...

# %%
# gan.save_models(models)
